# %%
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time
# %matplotlib qt
# %matplotlib inline
import pickle
calibration_flag = 0

# %%
def showImg(img):
    plt.imshow(img)
    plt.show()

# %% [markdown]
# ## Find Chessboard Corners

# %%
if calibration_flag == 1:
    # Set numb er of chessboard points
    nx = 9
    ny = 6

    # prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
    objp = np.zeros((ny*nx,3), np.float32)
    objp[:,:2] = np.mgrid[0:nx, 0:ny].T.reshape(-1,2)

    # Arrays to store object points and image points from all the images.
    objpoints = [] # 3d points in real world space
    imgpoints = [] # 2d points in image plane.

    # Make a list of calibration images
    images = glob.glob('camera_cal/calibration*.jpg')

    # Step through the list and search for chessboard corners
    for idx, fname in enumerate(images):
        img = cv2.imread(fname)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Find the chessboard corners
        ret, corners = cv2.findChessboardCorners(gray, (nx,ny), None)

        # If found, add object points, image points
        if ret == True:
            objpoints.append(objp)
            imgpoints.append(corners)

# %% [markdown]
# ## Create mtx and dist matrices to Calibrate Camera

# %%
if calibration_flag == 1:
    # Test undistortion on an image
    img = cv2.imread('test_images/test1.jpg')
    img_size = (img.shape[1], img.shape[0])

    # Do camera calibration given object points and image points
    ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, img_size, None, None)

    # undistort
    dst = cv2.undistort(img, mtx, dist, None, mtx)
    cv2.imwrite('camera_cal/test1_undist.jpg',dst)

    # Save the camera calibration result for later use (we won't worry about rvecs / tvecs)
    dist_pickle = {}
    dist_pickle["mtx"] = mtx
    dist_pickle["dist"] = dist
    # pickle.dump( dist_pickle, open( "camera_cal/dist_pickle.p", "wb" ) )
    
    ## CALIBRATION IMAGE FOR REPORT REQUIRED
    
    dst = cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)
    # Visualize undistortion
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))
    ax1.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    ax1.set_title('Original Image', fontsize=30)
    ax2.imshow(dst)
    ax2.set_title('Undistorted Image', fontsize=30)

# %% [markdown]
# ## Colour & Gradient Thresholding

# %%
##################################################
# Sobel Threshold
##################################################
def abs_sobel_thresh(img, orient='x', sobel_kernel=5, thresh=(0, 255)):  
    thresh_min = thresh[0]
    thresh_max = thresh[1]
    # Convert to grayscale
    # gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    gray = img
    # Apply x or y gradient with the OpenCV Sobel() function
    # and take the absolute value
    if orient == 'x':
        abs_sobel = np.absolute(cv2.Sobel(gray, cv2.CV_64F, 1, 0))
    if orient == 'y':
        abs_sobel = np.absolute(cv2.Sobel(gray, cv2.CV_64F, 0, 1))
    # Rescale back to 8 bit integer
    scaled_sobel = np.uint8(255*abs_sobel/np.max(abs_sobel))
    # Create a copy and apply the threshold
    binary_output = np.zeros_like(scaled_sobel)
    # Here I'm using inclusive (>=, <=) thresholds, but exclusive is ok too
    binary_output[(scaled_sobel >= thresh_min) & (scaled_sobel <= thresh_max)] = 1

    # Return the result
    return binary_output


##################################################
# Magnititude Thresholding - USEFUL CODE
##################################################
def mag_thresh(img, sobel_kernel=5, mag_thresh=(100, 255)):
    # Convert to grayscale
    #gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    gray = img
    # Take both Sobel x and y gradients
    sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=sobel_kernel)
    sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=sobel_kernel)
    # Calculate the gradient magnitude
    gradmag = np.sqrt(sobelx**2 + sobely**2)
    # Rescale to 8 bit
    scale_factor = np.max(gradmag)/255
    gradmag = (gradmag/scale_factor).astype(np.uint8)
    # Create a binary image of ones where threshold is met, zeros otherwise
    binary_output = np.zeros_like(gradmag)
    binary_output[(gradmag >= mag_thresh[0]) & (gradmag <= mag_thresh[1])] = 1

    # Return the binary image
    return binary_output


##################################################
# Gradient Direction for Feature Detection - USEFUL CODE
##################################################
def dir_threshold(img, sobel_kernel=3, thresh=(0, np.pi/2)):
    # Grayscale
    # gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    gray = img
    # Calculate the x and y gradients
    sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=sobel_kernel)
    sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=sobel_kernel)
    # Take the absolute value of the gradient direction,
    # apply a threshold, and create a binary image result
    absgraddir = np.arctan2(np.absolute(sobely), np.absolute(sobelx))
    binary_output =  np.zeros_like(absgraddir)
    binary_output[(absgraddir >= thresh[0]) & (absgraddir <= thresh[1])] = 1

    # Return the binary image
    return binary_output


##################################################
# Colour Spaces
##################################################
# Define a function that thresholds the S-channel of HLS
# Use exclusive lower bound (>) and inclusive upper (<=)
def hls_select(img, thresh=(0, 255)):
    # 1) Convert to HLS color space
    # 2) Apply a threshold to the S channel
    # 3) Return a binary image of threshold result
    
    # Convert to HLS colour space
    hls = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
    H = hls[:,:,0]
    L = hls[:,:,1]
    S = hls[:,:,2]
    # Apply a threshold to the S channel
    binary = np.zeros_like(S)
    binary[(S > thresh[0]) & (S <= thresh[1])] = 1
    
    return binary

##################################################
# My Pipeline
##################################################
def imagePipeline(image):
    # Sobel kernel size
    ksize = 5 
    sx_thresh = (20, 255)
    sy_thresh = (20, 255)
    
    image = np.copy(image)
    # Convert to HSV color space and separate the V channel
    hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HLS).astype(np.float)
    l_channel = hsv[:,:,1]
    s_channel = hsv[:,:,2]

    # Apply each of the thresholding functions
    gradx = abs_sobel_thresh(l_channel, orient='x', sobel_kernel=ksize, thresh=(20, 255))
    grady = abs_sobel_thresh(l_channel, orient='y', sobel_kernel=ksize, thresh=(20, 255))
    mag_binary = mag_thresh(l_channel, sobel_kernel=ksize, mag_thresh=(60, 255)) 
    dir_binary = dir_threshold(l_channel, sobel_kernel=ksize, thresh=(1.4, np.pi/2)) # Value is in radians div 180
    # Bonus
    hls_binary = hls_select(image, thresh=(90, 255))

    combined = np.zeros_like(dir_binary)
    combined[((gradx == 1) & (grady == 1)) | ((mag_binary == 1) & (dir_binary == 1)) | (hls_binary==1)] = 1
    
    return combined

# Testing
# image = cv2.imread('test_images/test2.jpg')
# img = imagePipeline(image)
# img = reproject(img, nx, ny, mtx, dist )  
# plotResult(image, img)

# %% [markdown]
# ## Plotting Function for Testing

# %%
def plotResult(original, new):
    # Plot the result
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 9))
    f.tight_layout()
    
    if len(original.shape) == 3:
        original = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
        cmap1=None
    else:
        cmap1='gray'
        
    ax1.imshow(original, cmap=cmap1)
    ax1.set_title('Original Image', fontsize=40)
    
    if len(new.shape) == 3:
        new = cv2.cvtColor(new, cv2.COLOR_BGR2RGB)
        cmap2=None
    else:
        cmap2='gray'
        
    ax2.imshow(new, cmap=cmap2)
    ax2.set_title('Pipeline Result', fontsize=40)
    plt.subplots_adjust(left=0., right=1, top=0.9, bottom=0.)

# %% [markdown]
# ## Tranform Image to Top View

# %%
def reproject(image, nx, ny, mtx, dist ):
    undist = cv2.undistort(image, mtx, dist, None, mtx)
    if image.shape == 3:
        # Colour
        gray = cv2.cvtColor(undist, cv2.COLOR_BGR2GRAY)
        img_size = (gray.shape[1], gray.shape[0])
    else:
        # B&W
        img_size = (image.shape[1], image.shape[0])
        
    # Working for full sized image
    src = np.float32([(200, 720), (580, 480), (720, 480), (1050, 700)])
    dst = np.float32([(280, 720), (400, 190), (920, 190), (960, 720)]) 

    # Given src and dst points, calculate the perspective transform matrix
    M = cv2.getPerspectiveTransform(src, dst)
    Minv = cv2.getPerspectiveTransform(dst, src)
    # Warp the image using OpenCV warpPerspective()
    warped = cv2.warpPerspective(image, M, img_size)
    return warped, Minv

# %% [markdown]
# ## Lane finding with convolutions

# %%
def window_mask(width, height, img_ref, center,level):
    output = np.zeros_like(img_ref)
    output[int(img_ref.shape[0]-(level+1)*height):int(img_ref.shape[0]-level*height),max(0,int(center-width/2)):min(int(center+width/2),img_ref.shape[1])] = 1
    return output

def find_window_centroids(warped, window_width, window_height, margin):

    window_centroids = [] # Store the (left,right) window centroid positions per level
    window = np.ones(window_width) # Create our window template that we will use for convolutions

    # First find the two starting positions for the left and right lane by using np.sum to get the vertical image slice
    # and then np.convolve the vertical image slice with the window template

    # Sum quarter bottom of image to get slice, could use a different ratio
    l_sum = np.sum(warped[int(3*warped.shape[0]/4):,:int(warped.shape[1]/2)], axis=0)
    l_center = np.argmax(np.convolve(window,l_sum))-window_width/2
    r_sum = np.sum(warped[int(3*warped.shape[0]/4):,int(warped.shape[1]/2):], axis=0)
    r_center = np.argmax(np.convolve(window,r_sum))-window_width/2+int(warped.shape[1]/2)

    # Add what we found for the first layer
    window_centroids.append((l_center,r_center))

    # Go through each layer looking for max pixel locations
    for level in range(1,(int)(warped.shape[0]/window_height)):
        # convolve the window into the vertical slice of the image
        image_layer = np.sum(warped[int(warped.shape[0]-(level+1)*window_height):int(warped.shape[0]-level*window_height),:], axis=0)
        conv_signal = np.convolve(window, image_layer)
        # Find the best left centroid by using past left center as a reference
        # Use window_width/2 as offset because convolution signal reference is at right side of window, not center of window
        offset = window_width/2
        l_min_index = int(max(l_center+offset-margin,0))
        l_max_index = int(min(l_center+offset+margin,warped.shape[1]))
        l_center = np.argmax(conv_signal[l_min_index:l_max_index])+l_min_index-offset
        # Find the best right centroid by using past right center as a reference
        r_min_index = int(max(r_center+offset-margin,0))
        r_max_index = int(min(r_center+offset+margin,warped.shape[1]))
        r_center = np.argmax(conv_signal[r_min_index:r_max_index])+r_min_index-offset
        # Add what we found for that layer
        window_centroids.append((l_center,r_center))

    return window_centroids

def findLanes(warped):
    # window settings
    window_width = 50
    window_height = 80 # Break image into 9 vertical layers since image height is 720
    margin = 100 # How much to slide left and right for searching

    window_centroids = find_window_centroids(warped, window_width, window_height, margin)
    pts_l = []
    pts_r = []
    # If we found any window centers
    if len(window_centroids) > 0:

        # Points used to draw all the left and right windows
        l_points = np.zeros_like(warped)
        r_points = np.zeros_like(warped)
        
        # Make some empty lists to store window centroids

        # Go through each level and draw the windows
        for level in range(0,len(window_centroids)):
            # Window_mask is a function to draw window areas
            l_mask = window_mask(window_width,window_height,warped,window_centroids[level][0],level)
            r_mask = window_mask(window_width,window_height,warped,window_centroids[level][1],level)
            # Add graphic points from window mask here to total pixels found
            l_points[(l_points == 255) | ((l_mask == 1) ) ] = 255
            r_points[(r_points == 255) | ((r_mask == 1) ) ] = 255

        # Draw the results
        template = np.array(r_points+l_points,np.uint8) # add both left and right window pixels together
        zero_channel = np.zeros_like(template) # create a zero color channel
        template = np.array(cv2.merge((zero_channel,template,zero_channel)),np.uint8) # make window pixels green
        warpage = np.array(cv2.merge((warped,warped,warped)),np.uint8) # making the original road pixels 3 color channels
        output = cv2.addWeighted(warpage, 1, template, 0.5, 0.0) # overlay the orignal road image with window results

    # If no window centers found, just display orginal road image
    else:
        output = np.array(cv2.merge((warped,warped,warped)),np.uint8)
       

    return output, l_points, r_points

# %% [markdown]
# ## Measure Curvature

# %%
# def measureCurve(leftx, rightx):  
def measureCurve(lx, ly, rx, ry):    
    
    # Fit a second order polynomial to pixel positions in each fake lane line
    left_fit = np.polyfit(ly, lx, 2)    
    left_fitx = left_fit[0]*ly**2 + left_fit[1]*ly + left_fit[2]
    right_fit = np.polyfit(ry, rx, 2)
    right_fitx = right_fit[0]*ry**2 + right_fit[1]*ry + right_fit[2]

    ## Convert curvature to metres
    # Define conversions in x and y from pixels space to meters
    ym_per_pix = 30.0/720.0 # meters per pixel in y dimension
    xm_per_pix = 3.7/700.0 # meters per pixel in x dimension
    
    y_eval = np.max(720)
    
    # Fit new polynomials to x,y in world space
    left_fit_cr = np.polyfit(ly*ym_per_pix, lx*xm_per_pix, 2)
    right_fit_cr = np.polyfit(ry*ym_per_pix, rx*xm_per_pix, 2)
    # Calculate the new radii of curvature
    left_curverad = ((1 + (2*left_fit_cr[0]*y_eval*ym_per_pix + left_fit_cr[1])**2)**1.5) / np.absolute(2*left_fit_cr[0])
    right_curverad = ((1 + (2*right_fit_cr[0]*y_eval*ym_per_pix + right_fit_cr[1])**2)**1.5) / np.absolute(2*right_fit_cr[0])
  
    return round(left_curverad, 1), round(right_curverad, 1), [left_fitx, right_fitx]

# %% [markdown]
# ## Get the X,Y for Reprojection

# %%
# # Get points
# %matplotlib qt
# image = cv2.imread('test_images/straight_lines1.jpg')
# showImg(image)

# %% [markdown]
# ## Identify the x and y positions of all nonzero pixels in the image

# %%
def img2XY(img):
    # Identify the x and y positions of all nonzero pixels in the image
    nonzero = img.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    return nonzerox, nonzeroy

# %% [markdown]
# ## Function Plots the green carpet on the lane of the original Image

# %%
def carpetPlotter(undist, warped, left_fitx, ly, right_fitx, ry, Minv ):
    # Create an image to draw the lines on
    warp_zero = np.zeros_like(warped).astype(np.uint8)
    color_warp = np.dstack((warp_zero, warp_zero, warp_zero))

    # Recast the x and y points into usable format for cv2.fillPoly()
    pts_left = np.array([np.transpose(np.vstack([left_fitx, ly]))])
    pts_right = np.array([np.flipud(np.transpose(np.vstack([right_fitx, ry])))])
    pts = np.hstack((pts_left, pts_right))

    # Draw the lane onto the warped blank image
    cv2.fillPoly(color_warp, np.int_([pts]), (0,255, 0))

    # Warp the blank back to original image space using inverse perspective matrix (Minv)
    newwarp = cv2.warpPerspective(color_warp, Minv, (image.shape[1], image.shape[0])) 
    # Combine the result with the original image
    result = cv2.addWeighted(undist, 1, newwarp, 0.3, 0)
    #plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
    return result

# %%
def onesTo255(img):
    # Convert 1's to 255
    img_bw = np.zeros_like(img)
    img_bw[img == 1] = 255
    img_bw = np.array(img_bw, dtype = np.uint8) 
    
    return img_bw

# %% [markdown]
# ## ESTIMATE THE OFFSET OF THE CAR FROM CENTRE

# %%
def getOffset(lx, ly, rx, ry):
    y_eval = 720
    xm_per_pix = 3.7/700.0 # meters per pixel in x dimension
    
    leftPos = lx[0]
    rightPos = rx[0]
    carDatum = 640
    
    laneWidth = rightPos - leftPos
    laneCentre = leftPos + laneWidth / 2
    # Offset w.r.t image axis
    offset_m = (carDatum - laneCentre) * xm_per_pix
    
    return round(offset_m, 1)

# %% [markdown]
# ## FLOW CONTROL
#
# The goals / steps of this project are the following:
#
# * Compute the camera calibration matrix and distortion coefficients given a set of chessboard images.
# * Apply a distortion correction to raw images.
# * Use color transforms, gradients, etc., to create a thresholded binary image.
# * Apply a perspective transform to rectify binary image ("birds-eye view").
# * Detect lane pixels and fit to find the lane boundary.
# * Determine the curvature of the lane and vehicle position with respect to center.
# * Warp the detected lane boundaries back onto the original image.
# * Output visual display of the lane boundaries and numerical estimation of lane curvature and vehicle position.

# %% [markdown]
# ## My Lane Finding Pipeline

# %%
def process_image(image):
    # Set number of chessboard points
    nx = 9
    ny = 6
    
    # Undistort (May need to get new coords for reproject)  => https://goo.gl/2aFqGL
    # image = cv2.undistort(image, mtx, dist, None, mtx)
    
    # Colour and Gradient Thresholding
    img = imagePipeline(image)    
    warped, Minv = reproject(img, nx, ny, mtx, dist )   
    
    # Convert 1's to 255
    img_bw = onesTo255(warped)
    
    # Find Lane Lines (takes a grayscale image 0-255)
    lanes, pts_l, pts_r = findLanes(img_bw) 
    
    # Turn Image into X and Y Coords
    lx, ly = img2XY(pts_l)
    rx, ry = img2XY(pts_r)
    
    left_curverad, right_curverad, fits = measureCurve(lx, ly, rx, ry)
    left_fitx = fits[0]
    right_fitx = fits[1]
    
    curveText = 'Curve Radii => Left ' + str(left_curverad) + 'm, Right ' + str(right_curverad) + 'm'
    
    # NOW ESTIMATE THE OFFSET OF THE CAR FROM CENTRE
    offset_m = getOffset(lx, ly, rx, ry)
    offsetText = 'Offset of vehicle is ' + str(offset_m) + 'm'
    
    # Plot the green carpet in lane
    carpet = carpetPlotter(image, warped, left_fitx, ly, right_fitx, ry, Minv )
    
    # Put text on frame
    colour = (0, 0, 0)
    thickness = 2
    scale = 0.7
    cv2.putText(carpet, curveText, (20, 50), cv2.FONT_HERSHEY_SIMPLEX, scale, colour, thickness)
    cv2.putText(carpet, offsetText, (20, 80), cv2.FONT_HERSHEY_SIMPLEX, scale, colour, thickness)



    return carpet

# %% [markdown]
# ## Test bed

# %%
# %matplotlib inline
images = glob.glob('test_images/test*.jpg')

# Load Pickled mtx, dist and M for image calibration and transformation
pickle_file = open( "camera_cal/dist_pickle.p", "rb" )
dist_pickle = pickle.load( pickle_file )
dist = dist_pickle['dist']
mtx = dist_pickle['mtx']

# Set number of chessboard points
nx = 9
ny = 6

# Step through the list of images
for idx, fname in enumerate(images):
    image = cv2.imread(fname)
    
    carpet = process_image(image)
    showImg(cv2.cvtColor(carpet, cv2.COLOR_BGR2RGB))
#     plotResult(carpet, lanes)
    
    # Save to file
    write_name = 'out/lanes_'+str(idx)+'.jpg'
    cv2.imwrite(write_name, lanes )

# %% [markdown]
# ## Test on Videos!
#
# **Note: if you get an `import error` when you run the next cell, try changing your kernel (select the Kernel menu above --> Change Kernel).  Still have problems?  Try relaunching Jupyter Notebook from the terminal prompt. Also, check out [this forum post](https://carnd-forums.udacity.com/questions/22677062/answers/22677109) for more troubleshooting tips.**
#
# **If you get an error that looks like this:**
# ```
# NeedDownloadError: Need ffmpeg exe.
# You can download it by calling:
# imageio.plugins.ffmpeg.download()
# ```
# **Follow the instructions in the error message and check out [this forum post](https://carnd-forums.udacity.com/display/CAR/questions/26218840/import-videofileclip-error) for more troubleshooting tips across operating systems.**

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# Load Pickled mtx, dist and M for image calibration and transformation
pickle_file = open( "camera_cal/dist_pickle.p", "rb" )
dist_pickle = pickle.load( pickle_file )
dist = dist_pickle['dist']
mtx = dist_pickle['mtx']

# %% [markdown]
# ## Project Video

# %%
output = 'project_video_output.mp4'
# A short subclip
clip1 = VideoFileClip("project_video.mp4").subclip(0,5)
#clip1 = VideoFileClip(""project_video.mp4")
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(output, audio=False)
# Out:
# [MoviePy] >>>> Building video project_video_output.mp4
# [MoviePy] Writing video project_video_output.mp4
#  96%|█████████▌| 25/26 [00:06<00:00,  3.59it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: project_video_output.mp4
#
# CPU times: user 6.38 s, sys: 1.47 s, total: 7.85 s
# Wall time: 7.37 s

# %%
output = 'challenge_output.mp4'
# A short subclip
clip1 = VideoFileClip("challenge_video.mp4").subclip(0,5)
#clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4")
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(output, audio=False)
# Out:
# Curve Radii => Left 164.9 m, Right 480.8 m
# Offset of vehicle is -0.3 m
# [MoviePy] >>>> Building video challenge_output.mp4
# [MoviePy] Writing video challenge_output.mp4
#   1%|          | 1/150 [00:00<00:42,  3.53it/s]
# Curve Radii => Left 164.9 m, Right 480.8 m
# Offset of vehicle is -0.3 m
#   1%|▏         | 2/150 [00:00<00:42,  3.52it/s]
# Curve Radii => Left 300.5 m, Right 2329.7 m
# Offset of vehicle is -0.3 m
#   2%|▏         | 3/150 [00:00<00:41,  3.56it/s]
# Curve Radii => Left 207.2 m, Right 481.0 m
# Offset of vehicle is -0.4 m
#   3%|▎         | 4/150 [00:01<00:40,  3.56it/s]
# Curve Radii => Left 203.9 m, Right 551.3 m
# Offset of vehicle is -0.4 m
#   3%|▎         | 5/150 [00:01<00:40,  3.57it/s]
# Curve Radii => Left 349.7 m, Right 7084.8 m
# Offset of vehicle is -0.3 m
#   4%|▍         | 6/150 [00:01<00:40,  3.59it/s]
# Curve Radii => Left 169.2 m, Right 15438.5 m
# Offset of vehicle is -0.1 m
#   5%|▍         | 7/150 [00:01<00:39,  3.64it/s]
# Curve Radii => Left 223.4 m, Right 531.8 m
# Offset of vehicle is -0.5 m
#   5%|▌         | 8/150 [00:02<00:39,  3.60it/s]
# Curve Radii => Left 197.6 m, Right 727.3 m
# Offset of vehicle is -0.2 m
#   6%|▌         | 9/150 [00:02<00:39,  3.58it/s]
# Curve Radii => Left 178.2 m, Right 1698.8 m
# Offset of vehicle is -0.2 m
#   7%|▋         | 10/150 [00:02<00:39,  3.59it/s]
# Curve Radii => Left 179.2 m, Right 439.9 m
# Offset of vehicle is -0.5 m
#   7%|▋         | 11/150 [00:03<00:38,  3.62it/s]
# Curve Radii => Left 155.2 m, Right 421.8 m
# Offset of vehicle is -0.4 m
#   8%|▊         | 12/150 [00:03<00:38,  3.63it/s]
# Curve Radii => Left 173.1 m, Right 748.5 m
# Offset of vehicle is -0.5 m
#   9%|▊         | 13/150 [00:03<00:37,  3.67it/s]
# Curve Radii => Left 159.7 m, Right 826.4 m
# Offset of vehicle is -0.4 m
#   9%|▉         | 14/150 [00:03<00:37,  3.61it/s]
# Curve Radii => Left 161.5 m, Right 230.5 m
# Offset of vehicle is 0.1 m
#  10%|█         | 15/150 [00:04<00:37,  3.61it/s]
# Curve Radii => Left 155.5 m, Right 566.0 m
# Offset of vehicle is -0.5 m
#  11%|█         | 16/150 [00:04<00:37,  3.62it/s]
# Curve Radii => Left 153.8 m, Right 650.6 m
# Offset of vehicle is -0.4 m
#  11%|█▏        | 17/150 [00:04<00:36,  3.62it/s]
# Curve Radii => Left 167.9 m, Right 738.3 m
# Offset of vehicle is -0.2 m
#  12%|█▏        | 18/150 [00:04<00:36,  3.62it/s]
# Curve Radii => Left 144.8 m, Right 477.5 m
# Offset of vehicle is -0.4 m
#  13%|█▎        | 19/150 [00:05<00:36,  3.60it/s]
# Curve Radii => Left 154.2 m, Right 1092.8 m
# Offset of vehicle is -0.2 m
#  13%|█▎        | 20/150 [00:05<00:36,  3.56it/s]
# Curve Radii => Left 160.0 m, Right 1193.2 m
# Offset of vehicle is -0.1 m
#  14%|█▍        | 21/150 [00:05<00:36,  3.57it/s]
# Curve Radii => Left 140.2 m, Right 1589.0 m
# Offset of vehicle is -0.0 m
#  15%|█▍        | 22/150 [00:06<00:35,  3.59it/s]
# Curve Radii => Left 161.8 m, Right 1288.2 m
# Offset of vehicle is -0.2 m
#  15%|█▌        | 23/150 [00:06<00:35,  3.58it/s]
# Curve Radii => Left 145.4 m, Right 544.2 m
# Offset of vehicle is -0.1 m
#  16%|█▌        | 24/150 [00:06<00:35,  3.58it/s]
# Curve Radii => Left 183.5 m, Right 769.7 m
# Offset of vehicle is -0.3 m
#  17%|█▋        | 25/150 [00:06<00:34,  3.59it/s]
# Curve Radii => Left 171.2 m, Right 4458.6 m
# Offset of vehicle is -0.3 m
#  17%|█▋        | 26/150 [00:07<00:34,  3.60it/s]
# Curve Radii => Left 180.5 m, Right 224.4 m
# Offset of vehicle is 0.1 m
#  18%|█▊        | 27/150 [00:07<00:34,  3.58it/s]
# Curve Radii => Left 170.7 m, Right 251.3 m
# Offset of vehicle is 0.1 m
#  19%|█▊        | 28/150 [00:07<00:33,  3.60it/s]
# Curve Radii => Left 172.3 m, Right 186.3 m
# Offset of vehicle is -0.0 m
#  19%|█▉        | 29/150 [00:08<00:33,  3.57it/s]
# Curve Radii => Left 387.4 m, Right 628.2 m
# Offset of vehicle is 0.1 m
#  20%|██        | 30/150 [00:08<00:33,  3.60it/s]
# Curve Radii => Left 173.1 m, Right 280.9 m
# Offset of vehicle is 0.1 m
#  21%|██        | 31/150 [00:08<00:33,  3.59it/s]
# Curve Radii => Left 169.0 m, Right 515.5 m
# Offset of vehicle is -0.7 m
#  21%|██▏       | 32/150 [00:08<00:32,  3.59it/s]
# Curve Radii => Left 161.9 m, Right 215.4 m
# Offset of vehicle is -0.7 m
#  22%|██▏       | 33/150 [00:09<00:32,  3.57it/s]
# Curve Radii => Left 179.0 m, Right 151.1 m
# Offset of vehicle is 0.3 m
#  23%|██▎       | 34/150 [00:09<00:32,  3.55it/s]
# Curve Radii => Left 177.3 m, Right 899.5 m
# Offset of vehicle is -0.3 m
#  23%|██▎       | 35/150 [00:09<00:32,  3.56it/s]
# Curve Radii => Left 170.7 m, Right 259.6 m
# Offset of vehicle is -0.8 m
#  24%|██▍       | 36/150 [00:10<00:32,  3.53it/s]
# Curve Radii => Left 387.8 m, Right 650.3 m
# Offset of vehicle is -0.3 m
#  25%|██▍       | 37/150 [00:10<00:31,  3.55it/s]
# Curve Radii => Left 107.6 m, Right 890.3 m
# Offset of vehicle is -0.3 m
#  25%|██▌       | 38/150 [00:10<00:31,  3.57it/s]
# Curve Radii => Left 109.2 m, Right 477.4 m
# Offset of vehicle is -0.9 m
#  26%|██▌       | 39/150 [00:10<00:30,  3.58it/s]
# Curve Radii => Left 114.6 m, Right 396.8 m
# Offset of vehicle is -0.8 m
#  27%|██▋       | 40/150 [00:11<00:30,  3.58it/s]
# Curve Radii => Left 106.2 m, Right 3043.4 m
# Offset of vehicle is -0.6 m
#  27%|██▋       | 41/150 [00:11<00:30,  3.59it/s]
# Curve Radii => Left 114.5 m, Right 7338.5 m
# Offset of vehicle is -0.6 m
#  28%|██▊       | 42/150 [00:11<00:29,  3.61it/s]
# Curve Radii => Left 148.6 m, Right 575.0 m
# Offset of vehicle is -0.9 m
#  29%|██▊       | 43/150 [00:11<00:29,  3.64it/s]
# Curve Radii => Left 136.3 m, Right 651.8 m
# Offset of vehicle is -0.9 m
#  29%|██▉       | 44/150 [00:12<00:29,  3.64it/s]
# Curve Radii => Left 118.6 m, Right 483.3 m
# Offset of vehicle is -1.0 m
#  30%|███       | 45/150 [00:12<00:28,  3.67it/s]
# Curve Radii => Left 113.0 m, Right 608.1 m
# Offset of vehicle is -1.0 m
#  31%|███       | 46/150 [00:12<00:28,  3.65it/s]
# Curve Radii => Left 117.4 m, Right 592.5 m
# Offset of vehicle is -1.0 m
#  31%|███▏      | 47/150 [00:13<00:28,  3.65it/s]
# Curve Radii => Left 109.4 m, Right 794.5 m
# Offset of vehicle is -1.0 m
#  32%|███▏      | 48/150 [00:13<00:28,  3.63it/s]
# Curve Radii => Left 2820.3 m, Right 719.8 m
# Offset of vehicle is -1.0 m
#  33%|███▎      | 49/150 [00:13<00:27,  3.62it/s]
# Curve Radii => Left 2990.4 m, Right 800.0 m
# Offset of vehicle is -1.1 m
#  33%|███▎      | 50/150 [00:13<00:27,  3.61it/s]
# Curve Radii => Left 100.9 m, Right 326.9 m
# Offset of vehicle is 0.2 m
#  34%|███▍      | 51/150 [00:14<00:26,  3.68it/s]
# Curve Radii => Left 191.7 m, Right 363.7 m
# Offset of vehicle is 0.3 m
#  35%|███▍      | 52/150 [00:14<00:26,  3.68it/s]
# Curve Radii => Left 1471.4 m, Right 506.6 m
# Offset of vehicle is 0.3 m
#  35%|███▌      | 53/150 [00:14<00:26,  3.72it/s]
# Curve Radii => Left 1.45028530739e+15 m, Right 1269.9 m
# Offset of vehicle is 0.6 m
#  36%|███▌      | 54/150 [00:14<00:25,  3.71it/s]
# Curve Radii => Left 1.45028530739e+15 m, Right 513.7 m
# Offset of vehicle is 0.3 m
#  37%|███▋      | 55/150 [00:15<00:25,  3.72it/s]
# Curve Radii => Left 1.45028530739e+15 m, Right 373.5 m
# Offset of vehicle is 0.2 m
#  37%|███▋      | 56/150 [00:15<00:25,  3.72it/s]
# Curve Radii => Left 189.2 m, Right 1413.8 m
# Offset of vehicle is 0.5 m
#  38%|███▊      | 57/150 [00:15<00:24,  3.74it/s]
# Curve Radii => Left 189.5 m, Right 1730.3 m
# Offset of vehicle is 0.5 m
#  39%|███▊      | 58/150 [00:16<00:24,  3.74it/s]
# Curve Radii => Left 10210.0 m, Right 205.1 m
# Offset of vehicle is 1.8 m
#  39%|███▉      | 59/150 [00:16<00:24,  3.72it/s]
# Curve Radii => Left 1.27633802731e+15 m, Right 384.4 m
# Offset of vehicle is 1.6 m
#  40%|████      | 60/150 [00:16<00:24,  3.72it/s]
# Curve Radii => Left 1.3434934257e+15 m, Right 652.3 m
# Offset of vehicle is 0.5 m
#  41%|████      | 61/150 [00:16<00:24,  3.67it/s]
# Curve Radii => Left 1.1828644211e+15 m, Right 1000.2 m
# Offset of vehicle is 0.5 m
#  41%|████▏     | 62/150 [00:17<00:23,  3.67it/s]
# Curve Radii => Left 1.22241992626e+15 m, Right 577.6 m
# Offset of vehicle is 0.1 m
#  42%|████▏     | 63/150 [00:17<00:23,  3.65it/s]
# Curve Radii => Left 61.5 m, Right 1303.4 m
# Offset of vehicle is 0.5 m
#  43%|████▎     | 64/150 [00:17<00:23,  3.67it/s]
# Curve Radii => Left 74.9 m, Right 814.8 m
# Offset of vehicle is 0.5 m
#  43%|████▎     | 65/150 [00:17<00:22,  3.71it/s]
# Curve Radii => Left 49.3 m, Right 249.9 m
# Offset of vehicle is 0.6 m
#  44%|████▍     | 66/150 [00:18<00:22,  3.66it/s]
# Curve Radii => Left 53.1 m, Right 266.5 m
# Offset of vehicle is 0.7 m
#  45%|████▍     | 67/150 [00:18<00:22,  3.72it/s]
# Curve Radii => Left 41.8 m, Right 976.3 m
# Offset of vehicle is 0.7 m
#  45%|████▌     | 68/150 [00:18<00:21,  3.73it/s]
# Curve Radii => Left 36.4 m, Right 164.4 m
# Offset of vehicle is 0.9 m
#  46%|████▌     | 69/150 [00:19<00:21,  3.74it/s]
# Curve Radii => Left 32.1 m, Right 159.3 m
# Offset of vehicle is 1.0 m
#  47%|████▋     | 70/150 [00:19<00:21,  3.76it/s]
# Curve Radii => Left 40.3 m, Right 146.3 m
# Offset of vehicle is 1.0 m
#  47%|████▋     | 71/150 [00:19<00:21,  3.75it/s]
# Curve Radii => Left 555.4 m, Right 132.1 m
# Offset of vehicle is -0.6 m
#  48%|████▊     | 72/150 [00:19<00:20,  3.73it/s]
# Curve Radii => Left 753.5 m, Right 286.2 m
# Offset of vehicle is 0.1 m
#  49%|████▊     | 73/150 [00:20<00:20,  3.69it/s]
# Curve Radii => Left 728.0 m, Right 101.2 m
# Offset of vehicle is -0.3 m
#  49%|████▉     | 74/150 [00:20<00:20,  3.66it/s]
# Curve Radii => Left 589.3 m, Right 185.9 m
# Offset of vehicle is -0.6 m
#  50%|█████     | 75/150 [00:20<00:20,  3.63it/s]
# Curve Radii => Left 177.4 m, Right 140.6 m
# Offset of vehicle is -0.6 m
#  51%|█████     | 76/150 [00:20<00:20,  3.63it/s]
# Curve Radii => Left 34.0 m, Right 127.1 m
# Offset of vehicle is 0.9 m
#  51%|█████▏    | 77/150 [00:21<00:20,  3.63it/s]
# Curve Radii => Left 881.5 m, Right 179.1 m
# Offset of vehicle is -0.6 m
#  52%|█████▏    | 78/150 [00:21<00:19,  3.64it/s]
# Curve Radii => Left 1088.3 m, Right 134.9 m
# Offset of vehicle is -0.5 m
#  53%|█████▎    | 79/150 [00:21<00:19,  3.65it/s]
# Curve Radii => Left 834.7 m, Right 275.1 m
# Offset of vehicle is -1.0 m
#  53%|█████▎    | 80/150 [00:22<00:19,  3.66it/s]
# Curve Radii => Left 37.0 m, Right 303.3 m
# Offset of vehicle is 0.4 m
#  54%|█████▍    | 81/150 [00:22<00:18,  3.74it/s]
# Curve Radii => Left 37.6 m, Right 1432.0 m
# Offset of vehicle is 0.4 m
#  55%|█████▍    | 82/150 [00:22<00:18,  3.76it/s]
# Curve Radii => Left 36.4 m, Right 104.7 m
# Offset of vehicle is 1.1 m
#  55%|█████▌    | 83/150 [00:22<00:17,  3.77it/s]
# Curve Radii => Left 35.9 m, Right 120.9 m
# Offset of vehicle is 1.5 m
#  56%|█████▌    | 84/150 [00:23<00:17,  3.80it/s]
# Curve Radii => Left 35.9 m, Right 771.6 m
# Offset of vehicle is 0.4 m
#  57%|█████▋    | 85/150 [00:23<00:16,  3.83it/s]
# Curve Radii => Left 40.7 m, Right 359.7 m
# Offset of vehicle is 1.8 m
#  57%|█████▋    | 86/150 [00:23<00:16,  3.80it/s]
# Curve Radii => Left 41.9 m, Right 113.9 m
# Offset of vehicle is 1.5 m
#  58%|█████▊    | 87/150 [00:23<00:16,  3.77it/s]
# Curve Radii => Left 39.3 m, Right 220.2 m
# Offset of vehicle is 1.0 m
#  59%|█████▊    | 88/150 [00:24<00:16,  3.76it/s]
# Curve Radii => Left 42.3 m, Right 715.1 m
# Offset of vehicle is 0.8 m
#  59%|█████▉    | 89/150 [00:24<00:16,  3.75it/s]
# Curve Radii => Left 42.7 m, Right 4206.6 m
# Offset of vehicle is 0.9 m
#  60%|██████    | 90/150 [00:24<00:16,  3.74it/s]
# Curve Radii => Left 41.1 m, Right 286.3 m
# Offset of vehicle is 0.9 m
#  61%|██████    | 91/150 [00:24<00:15,  3.71it/s]
# Curve Radii => Left 766.5 m, Right 120.8 m
# Offset of vehicle is -1.1 m
#  61%|██████▏   | 92/150 [00:25<00:15,  3.71it/s]
# Curve Radii => Left 854.5 m, Right 611.0 m
# Offset of vehicle is -0.5 m
#  62%|██████▏   | 93/150 [00:25<00:15,  3.71it/s]
# Curve Radii => Left 43.6 m, Right 20062.8 m
# Offset of vehicle is 1.1 m
#  63%|██████▎   | 94/150 [00:25<00:14,  3.77it/s]
# Curve Radii => Left 43.1 m, Right 3282.6 m
# Offset of vehicle is 1.0 m
#  63%|██████▎   | 95/150 [00:25<00:14,  3.78it/s]
# Curve Radii => Left 38.3 m, Right 233.5 m
# Offset of vehicle is 1.0 m
#  64%|██████▍   | 96/150 [00:26<00:14,  3.77it/s]
# Curve Radii => Left 38.3 m, Right 797.5 m
# Offset of vehicle is 1.4 m
#  65%|██████▍   | 97/150 [00:26<00:14,  3.74it/s]
# Curve Radii => Left 42.8 m, Right 404.5 m
# Offset of vehicle is 1.5 m
#  65%|██████▌   | 98/150 [00:26<00:13,  3.77it/s]
# Curve Radii => Left 1133.7 m, Right 264.7 m
# Offset of vehicle is 0.1 m
#  66%|██████▌   | 99/150 [00:27<00:13,  3.76it/s]
# Curve Radii => Left 53.2 m, Right 315.0 m
# Offset of vehicle is 2.0 m
#  67%|██████▋   | 100/150 [00:27<00:13,  3.69it/s]
# Curve Radii => Left 236.8 m, Right 204.9 m
# Offset of vehicle is 0.3 m
#  67%|██████▋   | 101/150 [00:27<00:13,  3.69it/s]
# Curve Radii => Left 238.7 m, Right 302.9 m
# Offset of vehicle is 0.8 m
#  68%|██████▊   | 102/150 [00:27<00:13,  3.64it/s]
# Curve Radii => Left 261.8 m, Right 363.0 m
# Offset of vehicle is 0.5 m
#  69%|██████▊   | 103/150 [00:28<00:12,  3.63it/s]
# Curve Radii => Left 262.9 m, Right 260172.8 m
# Offset of vehicle is 0.9 m
#  69%|██████▉   | 104/150 [00:28<00:12,  3.63it/s]
# Curve Radii => Left 256.8 m, Right 2569.5 m
# Offset of vehicle is 1.0 m
#  70%|███████   | 105/150 [00:28<00:12,  3.63it/s]
# Curve Radii => Left 239.3 m, Right 615.7 m
# Offset of vehicle is 1.1 m
#  71%|███████   | 106/150 [00:28<00:12,  3.64it/s]
# Curve Radii => Left 247.3 m, Right 310.0 m
# Offset of vehicle is 0.8 m
#  71%|███████▏  | 107/150 [00:29<00:11,  3.62it/s]
# Curve Radii => Left 487.2 m, Right 340.5 m
# Offset of vehicle is 0.5 m
#  72%|███████▏  | 108/150 [00:29<00:11,  3.63it/s]
# Curve Radii => Left 503.9 m, Right 235.4 m
# Offset of vehicle is 0.5 m
#  73%|███████▎  | 109/150 [00:29<00:11,  3.61it/s]
# Curve Radii => Left 334.8 m, Right 109.2 m
# Offset of vehicle is 1.5 m
#  73%|███████▎  | 110/150 [00:30<00:11,  3.63it/s]
# Curve Radii => Left 121.8 m, Right 1809.6 m
# Offset of vehicle is 0.9 m
#  74%|███████▍  | 111/150 [00:30<00:10,  3.62it/s]
# Curve Radii => Left 40.7 m, Right 623.1 m
# Offset of vehicle is 2.0 m
#  75%|███████▍  | 112/150 [00:30<00:10,  3.66it/s]
# Curve Radii => Left 105.8 m, Right 168.8 m
# Offset of vehicle is 1.8 m
#  75%|███████▌  | 113/150 [00:30<00:10,  3.69it/s]
# Curve Radii => Left 77.1 m, Right 375.6 m
# Offset of vehicle is 2.4 m
#  76%|███████▌  | 114/150 [00:31<00:09,  3.65it/s]
# Curve Radii => Left 78.8 m, Right 380.8 m
# Offset of vehicle is 2.4 m
#  77%|███████▋  | 115/150 [00:31<00:09,  3.67it/s]
# Curve Radii => Left 75.9 m, Right 477.9 m
# Offset of vehicle is 2.2 m
#  77%|███████▋  | 116/150 [00:31<00:09,  3.64it/s]
# Curve Radii => Left 133.4 m, Right 607.5 m
# Offset of vehicle is 2.1 m
#  78%|███████▊  | 117/150 [00:32<00:09,  3.62it/s]
# Curve Radii => Left 124.3 m, Right 3822.7 m
# Offset of vehicle is 2.6 m
#  79%|███████▊  | 118/150 [00:32<00:08,  3.62it/s]
# Curve Radii => Left 108.1 m, Right 524.3 m
# Offset of vehicle is 2.2 m
#  79%|███████▉  | 119/150 [00:32<00:08,  3.63it/s]
# Curve Radii => Left 87.5 m, Right 228.5 m
# Offset of vehicle is 1.8 m
#  80%|████████  | 120/150 [00:32<00:08,  3.62it/s]
# Curve Radii => Left 86.9 m, Right 341.0 m
# Offset of vehicle is 2.2 m
#  81%|████████  | 121/150 [00:33<00:08,  3.62it/s]
# Curve Radii => Left 79.8 m, Right 365.8 m
# Offset of vehicle is 2.2 m
#  81%|████████▏ | 122/150 [00:33<00:07,  3.61it/s]
# Curve Radii => Left 81.2 m, Right 353.4 m
# Offset of vehicle is 1.8 m
#  82%|████████▏ | 123/150 [00:33<00:07,  3.61it/s]
# Curve Radii => Left 83.4 m, Right 156.3 m
# Offset of vehicle is 1.8 m
#  83%|████████▎ | 124/150 [00:33<00:07,  3.64it/s]
# Curve Radii => Left 83.8 m, Right 1108.6 m
# Offset of vehicle is 2.0 m
#  83%|████████▎ | 125/150 [00:34<00:06,  3.67it/s]
# Curve Radii => Left 82.9 m, Right 1361.8 m
# Offset of vehicle is 2.1 m
#  84%|████████▍ | 126/150 [00:34<00:06,  3.69it/s]
# Curve Radii => Left 80.1 m, Right 1325.5 m
# Offset of vehicle is 2.0 m
#  85%|████████▍ | 127/150 [00:34<00:06,  3.72it/s]
# Curve Radii => Left 82.9 m, Right 270.1 m
# Offset of vehicle is 2.7 m
#  85%|████████▌ | 128/150 [00:35<00:05,  3.76it/s]
# Curve Radii => Left 101.1 m, Right 163.2 m
# Offset of vehicle is 2.1 m
#  86%|████████▌ | 129/150 [00:35<00:05,  3.79it/s]
# Curve Radii => Left 93.7 m, Right 180.1 m
# Offset of vehicle is 2.0 m
#  87%|████████▋ | 130/150 [00:35<00:05,  3.81it/s]
# Curve Radii => Left 102.8 m, Right 183.3 m
# Offset of vehicle is 2.1 m
#  87%|████████▋ | 131/150 [00:35<00:04,  3.87it/s]
# Curve Radii => Left 82.1 m, Right 5.43631689763e+15 m
# Offset of vehicle is 3.0 m
#  88%|████████▊ | 132/150 [00:36<00:04,  3.81it/s]
# Curve Radii => Left 72.9 m, Right 1.3586717044e+16 m
# Offset of vehicle is 3.1 m
#  89%|████████▊ | 133/150 [00:36<00:04,  3.80it/s]
# Curve Radii => Left 123.5 m, Right 160.2 m
# Offset of vehicle is 1.9 m
#  89%|████████▉ | 134/150 [00:36<00:04,  3.82it/s]
# Curve Radii => Left 93.9 m, Right 289.8 m
# Offset of vehicle is 2.0 m
#  90%|█████████ | 135/150 [00:36<00:03,  3.81it/s]
# Curve Radii => Left 63.8 m, Right 326.9 m
# Offset of vehicle is 1.8 m
#  91%|█████████ | 136/150 [00:37<00:03,  3.80it/s]
# Curve Radii => Left 96.5 m, Right 154.6 m
# Offset of vehicle is 1.4 m
#  91%|█████████▏| 137/150 [00:37<00:03,  3.81it/s]
# Curve Radii => Left 85.6 m, Right 497.8 m
# Offset of vehicle is 2.1 m
#  92%|█████████▏| 138/150 [00:37<00:03,  3.87it/s]
# Curve Radii => Left 80.0 m, Right 92.3 m
# Offset of vehicle is 2.1 m
#  93%|█████████▎| 139/150 [00:37<00:02,  3.87it/s]
# Curve Radii => Left 74.8 m, Right 72.6 m
# Offset of vehicle is 2.1 m
#  93%|█████████▎| 140/150 [00:38<00:02,  3.90it/s]
# Curve Radii => Left 62.8 m, Right 172.4 m
# Offset of vehicle is 1.2 m
#  94%|█████████▍| 141/150 [00:38<00:02,  3.83it/s]
# Curve Radii => Left 58.6 m, Right 100.3 m
# Offset of vehicle is 1.9 m
#  95%|█████████▍| 142/150 [00:38<00:02,  3.83it/s]
# Curve Radii => Left 54.4 m, Right 695.7 m
# Offset of vehicle is 1.9 m
#  95%|█████████▌| 143/150 [00:38<00:01,  3.80it/s]
# Curve Radii => Left 40.7 m, Right 226.5 m
# Offset of vehicle is 1.0 m
#  96%|█████████▌| 144/150 [00:39<00:01,  3.80it/s]
# Curve Radii => Left 42.3 m, Right 96.2 m
# Offset of vehicle is 2.0 m
#  97%|█████████▋| 145/150 [00:39<00:01,  3.78it/s]
# Curve Radii => Left 40.2 m, Right 150.0 m
# Offset of vehicle is 2.0 m
#  97%|█████████▋| 146/150 [00:39<00:01,  3.77it/s]
# Curve Radii => Left 40.4 m, Right 164.0 m
# Offset of vehicle is 2.1 m
#  98%|█████████▊| 147/150 [00:39<00:00,  3.73it/s]
# Curve Radii => Left 31.2 m, Right 150.5 m
# Offset of vehicle is 2.1 m
#  99%|█████████▊| 148/150 [00:40<00:00,  3.73it/s]
# Curve Radii => Left 585.7 m, Right 95.4 m
# Offset of vehicle is 0.8 m
#  99%|█████████▉| 149/150 [00:40<00:00,  3.74it/s]
# Curve Radii => Left 485.2 m, Right 271.3 m
# Offset of vehicle is 0.8 m
# 100%|██████████| 150/150 [00:40<00:00,  3.70it/s]
# Curve Radii => Left 846.5 m, Right 110.9 m
# Offset of vehicle is 0.7 m
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: challenge_output.mp4
#
# CPU times: user 38.4 s, sys: 8.69 s, total: 47.1 s
# Wall time: 41.7 s
